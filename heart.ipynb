# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score
# Import heart data from NLP.py
from NLP import extract_disease_data

# %%
# loading the csv data to a Pandas DataFrame
heart_data = pd.read_csv('heart_statlog_cleveland_hungary_final.csv')

# %%
# print first 5 rows of the dataset
heart_data.head()
# Out:
#    age   sex   chest pain type   resting bp s   cholesterol   \
# 0    60     0                 1            129           448
# 1    32     0                 1            155           299
# 2    52     1                 1            125           282
# 3    58     1                 0            168           390
# 4    28     0                 2            162           488
#
#    fasting blood sugar   resting ecg   max heart rate   exercise angina   \
# 0                     0             2              178                 0
# 1                     1             2              132                 0
# 2                     0             2              147                 0
# 3                     0             2              185                 0
# 4                     1             2              195                 1
#
#    oldpeak                  ST slope   target
# 0                 4.480656          0       1
# 1                 4.732703          0       0
# ...

# %%
# print last 5 rows of the dataset
heart_data.tail()
# Out:
#        age   sex   chest pain type   resting bp s   cholesterol   \
# 26710    57     1                 3            175           236
# 26711    29     1                 1            159           374
# 26712    66     1                 2            127           202
# 26713    50     1                 0            100           114
# 26714    54     1                 2            100           196
#
#        fasting blood sugar   resting ecg   max heart rate   exercise angina   \
# 26710                     1             0              110                 1
# 26711                     0             2              196                 1
# 26712                     1             2               97                 1
# 26713                     0             2              178                 0
# 26714                     1             2              177                 1
#
#        oldpeak                  ST slope   target
# 26710                 5.821612          1       1
# ...

# %%
# number of rows and columns in the dataset
heart_data.shape
# Out:
# (26715, 12)

# %%
# getting some info about the data
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26715 entries, 0 to 26714
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      26715 non-null  int64
#  1   sex                      26715 non-null  int64
#  2   chest pain type          26715 non-null  int64
#  3   resting bp s             26715 non-null  int64
#  4   cholesterol              26715 non-null  int64
#  5   fasting blood sugar      26715 non-null  int64
#  6   resting ecg              26715 non-null  int64
#  7   max heart rate           26715 non-null  int64
#  8   exercise angina          26715 non-null  int64
#  9   oldpeak                  26715 non-null  float64
#  10  ST slope                 26715 non-null  int64
#  11  target                   26715 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 2.4 MB

# %%
x=heart_data.drop(columns=['target'] )
y=heart_data['target']

# %%
print(x)
# Out:
#        age   sex   chest pain type   resting bp s   cholesterol   \
# 0        60     0                 1            129           448
# 1        32     0                 1            155           299
# 2        52     1                 1            125           282
# 3        58     1                 0            168           390
# 4        28     0                 2            162           488
# ...     ...   ...               ...            ...           ...
# 26710    57     1                 3            175           236
# 26711    29     1                 1            159           374
# 26712    66     1                 2            127           202
# 26713    50     1                 0            100           114
# 26714    54     1                 2            100           196
#
#        fasting blood sugar   resting ecg   max heart rate   exercise angina   \
# 0                         0             2              178                 0
# ...

# %%
print(y)
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 26710    1
# 26711    0
# 26712    1
# 26713    0
# 26714    1
# Name: target, Length: 26715, dtype: int64

# %%
scaler= StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
sd=scaler.transform(x)

# %%
print(sd)
# Out:
# [[ 0.93472266 -1.00469002 -0.44659442 ... -1.00408846  0.76355127
#   -1.22299991]
#  [-1.17482699 -1.00469002 -0.44659442 ... -1.00408846  0.9047901
#   -1.22299991]
#  [ 0.33199419  0.99533188 -0.44659442 ... -1.00408846 -0.02879859
#    0.00399583]
#  ...
#  [ 1.38676902  0.99533188  0.44763208 ...  0.99592818 -0.79908139
#    0.00399583]
#  [ 0.18131207  0.99533188 -1.34082092 ... -1.00408846 -1.25770806
#    1.23099157]
#  [ 0.48267631  0.99533188  0.44763208 ...  0.99592818  1.20044602
#    1.23099157]]

# %%
x=sd
y=heart_data['target']

# %%
print(x)
print(y)
# Out:
# [[ 0.93472266 -1.00469002 -0.44659442 ... -1.00408846  0.76355127
#   -1.22299991]
#  [-1.17482699 -1.00469002 -0.44659442 ... -1.00408846  0.9047901
#   -1.22299991]
#  [ 0.33199419  0.99533188 -0.44659442 ... -1.00408846 -0.02879859
#    0.00399583]
#  ...
#  [ 1.38676902  0.99533188  0.44763208 ...  0.99592818 -0.79908139
#    0.00399583]
#  [ 0.18131207  0.99533188 -1.34082092 ... -1.00408846 -1.25770806
#    1.23099157]
#  [ 0.48267631  0.99533188  0.44763208 ...  0.99592818  1.20044602
#    1.23099157]]
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 26710    1
# 26711    0
# 26712    1
# 26713    0
# 26714    1
# Name: target, Length: 26715, dtype: int64

# %%
X_train , X_test , Y_train , Y_test =train_test_split(x ,y ,test_size=0.2 ,stratify=y ,random_state=2)

# %%
print(x.shape ,X_train.shape ,X_test.shape)
# Out:
# (26715, 11) (21372, 11) (5343, 11)

# %%
classifier = svm.SVC(kernel='linear')

# %%
#training the support vector Machine Classifier

classifier.fit(X_train ,Y_train)
# Out:
# SVC(kernel='linear')

# %%
#accuracy score training data
X_train_pred= classifier.predict(X_train)
training_data_accuracy=accuracy_score(X_train_pred ,Y_train)

# %%
print('accuracy score of the training data : ' , training_data_accuracy )
# Out:
# accuracy score of the training data :  0.5087965562418117

# %%
#accuracy score on test data
X_test_pred= classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_pred ,Y_test)

# %%
print('accuracy score of the test data : ' , test_data_accuracy )
# Out:
# accuracy score of the test data :  0.49635036496350365

# %%
import joblib 

joblib.dump(classifier , 'heartmodel.pkl')

joblib.dump(scaler, 'scaler1.pkl')
# Out:
# ['scaler1.pkl']

# %%
if __name__ == "__main__":
    
    clinical_note = input('enter your EHR')
    disease_name = "heart"
    
    if clinical_note:
        heart_data = extract_disease_data(disease_name, clinical_note)
    
        
        if heart_data:
     
            
                ind_nparr = np.asarray(heart_data)
                ind_reshaped = ind_nparr.reshape(1, -1)
                
                # Assuming 'scaler' is defined elsewhere
                std_data = scaler.transform(ind_reshaped)

                print(std_data)

                # Assuming 'classifier' is defined elsewhere
                prediction = classifier.predict(std_data)

                print(prediction)

                if prediction[0] == 0:
                    print('The patient does not have heart disease.')
                else:
                    print('The patient has heart disease.')
        else:
                print("No numeric heart disease data found in the clinical note.")
    else:
            print("No heart disease data found in the clinical note.")
# Out:
# [[-7.22780635e-01  9.95331876e-01 -4.46594420e-01 -8.63645061e-01
#   -8.15958908e-01  2.82998511e+02  3.62614617e-03  3.95071542e-01
#    9.95928185e-01 -6.26528021e-01  1.23099157e+00]]
# [1]
# The patient has heart disease.
# C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
