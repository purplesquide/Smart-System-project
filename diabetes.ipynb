# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

from NLP import  extract_disease_data
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df= pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies   Glucose   BloodPressure   SkinThickness   Insulin   \
# 0             6       148              72              35         0
# 1             1        85              66              29         0
# 2             8       183              64               0         0
# 3             1        89              66              23        94
# 4             0       137              40              35       168
#
#    BMI                  DiabetesPedigreeFunction   Age   Outcome
# 0                 33.6                      0.627    50        1
# 1                 26.6                      0.351    31        0
# 2                 23.3                      0.672    32        1
# 3                 28.1                      0.167    21        0
# 4                 43.1                      2.288    33        1

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose   BloodPressure   SkinThickness     Insulin   \
# Outcome
# 0            4.907965  124.283053      103.381835       47.504884  144.793475
# 1            4.983769  125.289445      104.537957       48.596734  148.586249
#
#          BMI                  DiabetesPedigreeFunction        Age
# Outcome
# 0                  27.749821                   0.970288  49.268754
# 1                  27.727392                   0.979724  49.575461

# %%
x=df.drop(columns=['Outcome'] )
y=df['Outcome']

# %%
print(x)
# Out:
#        Pregnancies   Glucose   BloodPressure   SkinThickness   Insulin   \
# 0                 6       148              72              35         0
# 1                 1        85              66              29         0
# 2                 8       183              64               0         0
# 3                 1        89              66              23        94
# 4                 0       137              40              35       168
# ...             ...       ...             ...             ...       ...
# 19845             3       178             100              93        70
# 19846             7       163              68              52       193
# 19847             6       172             103              57       191
# 19848            10        61             109              18         0
# 19849             1        77             139              99       178
#
#        BMI                  DiabetesPedigreeFunction   Age
# ...

# %%
print(y)
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 19845    1
# 19846    0
# 19847    1
# 19848    0
# 19849    1
# Name: Outcome, Length: 19850, dtype: int64

# %% [markdown]
# data standarization

# %%
scaler= StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
sd=scaler.transform(x)

# %%
print(sd)
# Out:
# [[ 0.33250461  0.53494432 -1.18626682 ...  0.80502246 -0.60361818
#    0.03271585]
#  [-1.24460806 -0.91682667 -1.40897339 ... -0.15638095 -1.08234573
#   -1.0427468 ]
#  [ 0.96334968  1.34148376 -1.48320891 ... -0.60961399 -0.52556477
#   -0.9861435 ]
#  ...
#  [ 0.33250461  1.08799994 -0.03561622 ... -0.30648865  1.34889799
#    0.08931915]
#  [ 1.59419475 -1.46988229  0.18709035 ...  0.53946519 -0.62112161
#   -1.0993501 ]
#  [-1.24460806 -1.10117855  1.30062318 ... -0.93359891  1.21559938
#    0.65535212]]

# %%
x=sd
y=df['Outcome']

# %%
print(x)
print(y)
# Out:
# [[ 0.33250461  0.53494432 -1.18626682 ...  0.80502246 -0.60361818
#    0.03271585]
#  [-1.24460806 -0.91682667 -1.40897339 ... -0.15638095 -1.08234573
#   -1.0427468 ]
#  [ 0.96334968  1.34148376 -1.48320891 ... -0.60961399 -0.52556477
#   -0.9861435 ]
#  ...
#  [ 0.33250461  1.08799994 -0.03561622 ... -0.30648865  1.34889799
#    0.08931915]
#  [ 1.59419475 -1.46988229  0.18709035 ...  0.53946519 -0.62112161
#   -1.0993501 ]
#  [-1.24460806 -1.10117855  1.30062318 ... -0.93359891  1.21559938
#    0.65535212]]
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 19845    1
# 19846    0
# 19847    1
# 19848    0
# 19849    1
# Name: Outcome, Length: 19850, dtype: int64

# %% [markdown]
# Train Test Split

# %%
X_train , X_test , Y_train , Y_test =train_test_split(x ,y ,test_size=0.2 ,stratify=y ,random_state=2)

# %%
print(x.shape ,X_train.shape ,X_test.shape)
# Out:
# (19850, 8) (15880, 8) (3970, 8)

# %% [markdown]
# Training the model

# %%
classifier = svm.SVC(kernel='linear')

# %%
#training the support vector Machine Classifier

classifier.fit(X_train ,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
#accuracy score training data
X_train_pred= classifier.predict(X_train)
training_data_accuracy=accuracy_score(X_train_pred ,Y_train)

# %%
print('accuracy score of the training data : ' , training_data_accuracy )
# Out:
# accuracy score of the training data :  0.514609571788413

# %%
#accuracy score on test data
X_test_pred= classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_pred ,Y_test)

# %%
print('accuracy score of the test data : ' , test_data_accuracy )
# Out:
# accuracy score of the test data :  0.5083123425692695

# %%
import joblib 

joblib.dump(classifier , 'diabetesmodel.pkl')

joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %% [markdown]
# Making a predicting System

# %%
if __name__ == "__main__":
   
    clinical_note = input('enter clinical note')

    if clinical_note:
        # Extract diabetes data
        diabetes_data = extract_disease_data('diabetes', clinical_note)
        print(diabetes_data)
        if diabetes_data:
            ind_nparr = np.asarray(diabetes_data)
            ind_reshaped = ind_nparr.reshape(1, -1)

            # Assuming 'scaler' is defined elsewhere
            std_data = scaler.transform(ind_reshaped)

            print(std_data)

            # Assuming 'classifier' is defined elsewhere
            prediction = classifier.predict(std_data)

            print(prediction)

            if prediction[0] == 0:
                print('The patient is not diabetic.')
            else:
                print('The patient is diabetic.')
        else:
            print("No diabetes data found in the clinical note.")
